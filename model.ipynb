# %%
import numpy as np
import pandas as pd

# %%
np.random.seed(20250501)

# %% [markdown]
# ---
#
# # Dimensions Set-up

# %% [markdown]
# ### Period

# %%
periods = pd.date_range("2024-01-01", periods=24, freq="MS").strftime("%Y-%m")

# %% [markdown]
# ### Plant

# %%
n_plant = 6
base_cc_count = 10

# PLANTS SIZE
raw_scale = np.random.lognormal(mean=0.0, sigma=0.25, size=n_plant)
scale = raw_scale / raw_scale.mean()   # normalize around 1.0

# PLANTS BIASES
# automation: random factor representing plant automation level (-1 to 1)
# dm_bias: positive bias for high-automation plants (more efficient materials usage)
# dl_bias: negative bias for high-automation plants (less labor needed)
automation = np.random.uniform(-1, 1, n_plant)
dm_bias = np.clip(0.03 * automation, -0.05, 0.05)
dl_bias = np.clip(-0.03 * automation, -0.05, 0.05)

# PRODUCTION vs SUPPORTING CC RATIO
# Higher automation = more supporting CCs needed (less production)
# Larger plants = more supporting CCs needed (less production)
prod_cc_ratio = np.clip(0.75 - 0.15 * automation - 0.10 * (scale - 1), 0.60, 0.85)

# RM/PM RATIO based on plant scale and automation
# Larger/more automated plants have better material control → higher RM ratio
base_rm_ratio = 0.77
rm_ratio = np.clip(
    base_rm_ratio + 0.05 * automation + 0.03 * (scale - 1),
    0.65, 0.80
)

# OH-specific split: high automation → more fixed costs (depreciation, maintenance)
oh_fixed_ratio = 0.35 + 0.15 * automation  # 20–50% fixed depending on automation
oh_var_ratio = 1 - oh_fixed_ratio

plants = {
    f"PLANT {i+1:d}": {
        "SCALE": round(scale[i], 3),
        "AUTOMATION_INDEX": round(automation[i], 3),
        "DM_BIAS": round(dm_bias[i], 3),
        "DL_BIAS": round(dl_bias[i], 3),
        "CC_COUNT": max(3, int(np.random.poisson(base_cc_count*round(scale[i], 3)))),
        "PROD_CC_RATIO": round(prod_cc_ratio[i], 3),
        "PROD_VOLATILITY": round(np.random.uniform(0.05, 0.2), 3),
        "RM_RATIO": round(rm_ratio[i], 3),
        "PM_RATIO": round(1 - rm_ratio[i], 3),
        "OH_FIXED_RATIO": round(oh_fixed_ratio[i], 3),
        "OH_VAR_RATIO": round(oh_var_ratio[i], 3),
    }
    for i in range(n_plant)
}

plant_df = pd.DataFrame.from_dict(plants, orient="index")
plant_df.index.name = "PLANT"
plant_df
# Out:
#          SCALE  AUTOMATION_INDEX  DM_BIAS  DL_BIAS  CC_COUNT  PROD_CC_RATIO  \
# PLANT
# PLANT 1  0.622            -0.584   -0.018    0.018         4          0.850
# PLANT 2  1.158            -0.782   -0.023    0.023         6          0.850
# PLANT 3  0.984            -0.173   -0.005    0.005        12          0.778
# PLANT 4  1.293             0.370    0.011   -0.011        11          0.665
# PLANT 5  0.913            -0.963   -0.029    0.029         6          0.850
# PLANT 6  1.029            -0.894   -0.027    0.027         8          0.850
#
#          PROD_VOLATILITY  RM_RATIO  PM_RATIO  OH_FIXED_RATIO  OH_VAR_RATIO
# PLANT
# PLANT 1            0.077     0.729     0.271           0.262         0.738
# PLANT 2            0.059     0.736     0.264           0.233         0.767
# PLANT 3            0.130     0.761     0.239           0.324         0.676
# PLANT 4            0.090     0.797     0.203           0.406         0.594
# PLANT 5            0.144     0.719     0.281           0.206         0.794
# PLANT 6            0.125     0.726     0.274           0.216         0.784

# %% [markdown]
# ### Cost Centers

# %%
cc_map = {}
for i, plant in enumerate(plants.keys()):
    n_cc = plants[plant]['CC_COUNT']
    n_prod = max(1, int(n_cc * plants[plant]['PROD_CC_RATIO']))
    n_support = n_cc - n_prod
    
    prod_ccs = [f"CC{i+1:03d}P{j:02d}" for j in range(1, n_prod + 1)]
    support_ccs = [f"CC{i+1:03d}S{j:02d}" for j in range(1, n_support + 1)]
    cc_map[plant] = prod_ccs + support_ccs

cc_df = (
    pd.DataFrame(
        [
            (plant, cc, "Production" if "P" in cc else "Supporting")
            for plant, ccs in cc_map.items()
            for cc in ccs
        ],
        columns=["PLANT", "COST_CENTER", "CAT_CC"]
    )
)
cc_df
# Out:
#       PLANT COST_CENTER      CAT_CC
# 0   PLANT 1    CC001P01  Production
# 1   PLANT 1    CC001P02  Production
# 2   PLANT 1    CC001P03  Production
# 3   PLANT 1    CC001S01  Supporting
# 4   PLANT 2    CC002P01  Production
# 5   PLANT 2    CC002P02  Production
# 6   PLANT 2    CC002P03  Production
# 7   PLANT 2    CC002P04  Production
# 8   PLANT 2    CC002P05  Production
# 9   PLANT 2    CC002S01  Supporting
# 10  PLANT 3    CC003P01  Production
# 11  PLANT 3    CC003P02  Production
# 12  PLANT 3    CC003P03  Production
# 13  PLANT 3    CC003P04  Production
# 14  PLANT 3    CC003P05  Production
# 15  PLANT 3    CC003P06  Production
# 16  PLANT 3    CC003P07  Production
# 17  PLANT 3    CC003P08  Production
# 18  PLANT 3    CC003P09  Production
# 19  PLANT 3    CC003S01  Supporting
# 20  PLANT 3    CC003S02  Supporting
# 21  PLANT 3    CC003S03  Supporting
# 22  PLANT 4    CC004P01  Production
# 23  PLANT 4    CC004P02  Production
# 24  PLANT 4    CC004P03  Production
# 25  PLANT 4    CC004P04  Production
# 26  PLANT 4    CC004P05  Production
# 27  PLANT 4    CC004P06  Production
# 28  PLANT 4    CC004P07  Production
# 29  PLANT 4    CC004S01  Supporting
# 30  PLANT 4    CC004S02  Supporting
# 31  PLANT 4    CC004S03  Supporting
# 32  PLANT 4    CC004S04  Supporting
# 33  PLANT 5    CC005P01  Production
# 34  PLANT 5    CC005P02  Production
# 35  PLANT 5    CC005P03  Production
# 36  PLANT 5    CC005P04  Production
# 37  PLANT 5    CC005P05  Production
# 38  PLANT 5    CC005S01  Supporting
# 39  PLANT 6    CC006P01  Production
# 40  PLANT 6    CC006P02  Production
# 41  PLANT 6    CC006P03  Production
# 42  PLANT 6    CC006P04  Production
# 43  PLANT 6    CC006P05  Production
# 44  PLANT 6    CC006P06  Production
# 45  PLANT 6    CC006S01  Supporting
# 46  PLANT 6    CC006S02  Supporting

# %% [markdown]
# ### COA / Cost Elements

# %%
cost_elements = pd.DataFrame(
    [
        ("DM", "RM"),
        ("DM", "PM"),
        ("DL", "DL"),
        ("OH", "OH_FIX"),
        ("OH", "OH_VAR"),
    ],
    columns=["CAT_GL", "COST_ELEMENT"]
)
cost_elements
# Out:
#   CAT_GL COST_ELEMENT
# 0     DM           RM
# 1     DM           PM
# 2     DL           DL
# 3     OH       OH_FIX
# 4     OH       OH_VAR

# %%
elasticity_range = {
    "RM": (0.85, 0.95),
    "PM": (0.85, 0.95),
    "DL": (0.60, 0.80),
    "OH_VAR": (0.90, 1.05),
    "OH_FIX": (0.00, 0.00),
}

elasticity_table = (
    pd.MultiIndex.from_product(
        [plants.keys(), elasticity_range.keys()],
        names=["PLANT", "COST_ELEMENT"]
    )
    .to_frame(index=False)
)

elasticity_table["ELASTICITY"] = elasticity_table["COST_ELEMENT"].apply(
    lambda x: np.random.uniform(*elasticity_range[x])
)
elasticity_table
# Out:
#       PLANT COST_ELEMENT  ELASTICITY
# 0   PLANT 1           RM    0.932576
# 1   PLANT 1           PM    0.891600
# 2   PLANT 1           DL    0.721245
# 3   PLANT 1       OH_VAR    0.900185
# 4   PLANT 1       OH_FIX    0.000000
# 5   PLANT 2           RM    0.876508
# 6   PLANT 2           PM    0.933401
# 7   PLANT 2           DL    0.608891
# 8   PLANT 2       OH_VAR    0.964370
# 9   PLANT 2       OH_FIX    0.000000
# 10  PLANT 3           RM    0.927072
# 11  PLANT 3           PM    0.879254
# 12  PLANT 3           DL    0.623582
# 13  PLANT 3       OH_VAR    1.017765
# 14  PLANT 3       OH_FIX    0.000000
# 15  PLANT 4           RM    0.909807
# 16  PLANT 4           PM    0.868580
# 17  PLANT 4           DL    0.688662
# 18  PLANT 4       OH_VAR    0.927816
# 19  PLANT 4       OH_FIX    0.000000
# 20  PLANT 5           RM    0.856968
# 21  PLANT 5           PM    0.850316
# 22  PLANT 5           DL    0.608298
# 23  PLANT 5       OH_VAR    1.010506
# 24  PLANT 5       OH_FIX    0.000000
# 25  PLANT 6           RM    0.926873
# 26  PLANT 6           PM    0.907634
# 27  PLANT 6           DL    0.661586
# 28  PLANT 6       OH_VAR    1.031191
# 29  PLANT 6       OH_FIX    0.000000

# %% [markdown]
# ### Finished Goods

# %%
n_goods = 5
goods = [f"FG{i+1:02d}" for i in range(n_goods)]
goods
# Out:
# ['FG01', 'FG02', 'FG03', 'FG04', 'FG05']

# %% [markdown]
# ---
#
# # Fact Table Frame Skeleton

# %%
df = cc_df.assign(key=1).merge(
    pd.DataFrame({"PERIOD": periods, "key": 1}),
    on="key"
).drop("key", axis=1)
df.head(5)
# Out:
#      PLANT COST_CENTER      CAT_CC   PERIOD
# 0  PLANT 1    CC001P01  Production  2024-01
# 1  PLANT 1    CC001P01  Production  2024-02
# 2  PLANT 1    CC001P01  Production  2024-03
# 3  PLANT 1    CC001P01  Production  2024-04
# 4  PLANT 1    CC001P01  Production  2024-05

# %%
# cc_weight = np.random.randint(4,7,size=(len(cost_elements), len(cc_df)))
cc_weight = np.random.uniform(4, 7, size=(len(df), len(cost_elements)))
df[cost_elements['COST_ELEMENT']] = cc_weight

df[cost_elements['COST_ELEMENT']] = df[cost_elements['COST_ELEMENT']] / df.groupby(['PERIOD', 'PLANT', 'CAT_CC'])[cost_elements['COST_ELEMENT']].transform('sum')
df['QTY'] = (df['RM'] + df['PM']) / 2

df.head(10)
# Out:
#      PLANT COST_CENTER      CAT_CC   PERIOD        RM        PM        DL  \
# 0  PLANT 1    CC001P01  Production  2024-01  0.292179  0.389361  0.296544
# 1  PLANT 1    CC001P01  Production  2024-02  0.316834  0.317132  0.351508
# 2  PLANT 1    CC001P01  Production  2024-03  0.316233  0.365736  0.289624
# 3  PLANT 1    CC001P01  Production  2024-04  0.301176  0.346388  0.336764
# 4  PLANT 1    CC001P01  Production  2024-05  0.256346  0.333194  0.292261
# 5  PLANT 1    CC001P01  Production  2024-06  0.379955  0.296804  0.353627
# 6  PLANT 1    CC001P01  Production  2024-07  0.301213  0.349978  0.303208
# 7  PLANT 1    CC001P01  Production  2024-08  0.324546  0.375589  0.282978
# 8  PLANT 1    CC001P01  Production  2024-09  0.265990  0.288597  0.295224
# 9  PLANT 1    CC001P01  Production  2024-10  0.376596  0.371945  0.292846
#
#      OH_FIX    OH_VAR       QTY
# 0  0.268536  0.380160  0.340770
# 1  0.315923  0.356928  0.316983
# 2  0.286031  0.362550  0.340984
# 3  0.326478  0.336176  0.323782
# 4  0.320501  0.414162  0.294770
# 5  0.342345  0.326490  0.338380
# 6  0.318280  0.264040  0.325595
# 7  0.309849  0.310743  0.350068
# 8  0.300253  0.322719  0.277294
# 9  0.333149  0.338964  0.374271

# %%
# CHECKING
df.groupby(['PERIOD', 'PLANT', 'CAT_CC']).agg({ce: 'sum' for ce in cost_elements['COST_ELEMENT']}).map(lambda x: round(x, 1) == 1.0).loc[lambda x: ~x['OH_FIX']]
# Out:
# Empty DataFrame
# Columns: [RM, PM, DL, OH_FIX, OH_VAR]
# Index: []

# %% [markdown]
# ---
#
# # Qty & Cost Modelling

# %% [markdown]
# ### **1. BP**

# %%
pp = df[["PERIOD", "PLANT"]].drop_duplicates()

pp["ACTIVITY_INDEX"] = np.clip(
    np.random.normal(1.0, 0.1, len(pp)),
    0.8, 1.2
)

pp = pp.merge(plant_df, on="PLANT")
pp.head(5)
# Out:
#     PERIOD    PLANT  ACTIVITY_INDEX  SCALE  AUTOMATION_INDEX  DM_BIAS  \
# 0  2024-01  PLANT 1        1.079289  0.622            -0.584   -0.018
# 1  2024-02  PLANT 1        0.891325  0.622            -0.584   -0.018
# 2  2024-03  PLANT 1        1.085186  0.622            -0.584   -0.018
# 3  2024-04  PLANT 1        1.100785  0.622            -0.584   -0.018
# 4  2024-05  PLANT 1        0.909974  0.622            -0.584   -0.018
#
#    DL_BIAS  CC_COUNT  PROD_CC_RATIO  PROD_VOLATILITY  RM_RATIO  PM_RATIO  \
# 0    0.018         4           0.85            0.077     0.729     0.271
# 1    0.018         4           0.85            0.077     0.729     0.271
# 2    0.018         4           0.85            0.077     0.729     0.271
# 3    0.018         4           0.85            0.077     0.729     0.271
# 4    0.018         4           0.85            0.077     0.729     0.271
#
#    OH_FIXED_RATIO  OH_VAR_RATIO
# 0           0.262         0.738
# 1           0.262         0.738
# 2           0.262         0.738
# 3           0.262         0.738
# 4           0.262         0.738

# %% [markdown]
# #### Plant Level

# %%
base_qty = 10_000
cv = 0.12  # Coefficient of variation (adjust based on your volatility assumptions)
bound_pct = 0.30  # ±30% bounds

mean_qty = base_qty * pp["SCALE"] * pp["ACTIVITY_INDEX"]
pp["QTY"] = np.clip(
    np.random.normal(mean_qty, mean_qty * pp["PROD_VOLATILITY"]),
    mean_qty * (1 - bound_pct),
    mean_qty * (1 + bound_pct)
).astype(int)
# df = df.merge(pp, on=["PERIOD", "PLANT"])
# df
pp
# Out:
#       PERIOD    PLANT  ACTIVITY_INDEX  SCALE  AUTOMATION_INDEX  DM_BIAS  \
# 0    2024-01  PLANT 1        1.079289  0.622            -0.584   -0.018
# 1    2024-02  PLANT 1        0.891325  0.622            -0.584   -0.018
# 2    2024-03  PLANT 1        1.085186  0.622            -0.584   -0.018
# 3    2024-04  PLANT 1        1.100785  0.622            -0.584   -0.018
# 4    2024-05  PLANT 1        0.909974  0.622            -0.584   -0.018
# ..       ...      ...             ...    ...               ...      ...
# 139  2025-08  PLANT 6        0.964960  1.029            -0.894   -0.027
# 140  2025-09  PLANT 6        1.088843  1.029            -0.894   -0.027
# 141  2025-10  PLANT 6        1.200000  1.029            -0.894   -0.027
# 142  2025-11  PLANT 6        0.906906  1.029            -0.894   -0.027
# 143  2025-12  PLANT 6        1.108710  1.029            -0.894   -0.027
#
#      DL_BIAS  CC_COUNT  PROD_CC_RATIO  PROD_VOLATILITY  RM_RATIO  PM_RATIO  \
# 0      0.018         4           0.85            0.077     0.729     0.271
# 1      0.018         4           0.85            0.077     0.729     0.271
# 2      0.018         4           0.85            0.077     0.729     0.271
# 3      0.018         4           0.85            0.077     0.729     0.271
# 4      0.018         4           0.85            0.077     0.729     0.271
# ..       ...       ...            ...              ...       ...       ...
# 139    0.027         8           0.85            0.125     0.726     0.274
# 140    0.027         8           0.85            0.125     0.726     0.274
# 141    0.027         8           0.85            0.125     0.726     0.274
# 142    0.027         8           0.85            0.125     0.726     0.274
# 143    0.027         8           0.85            0.125     0.726     0.274
#
#      OH_FIXED_RATIO  OH_VAR_RATIO    QTY
# 0             0.262         0.738   6665
# 1             0.262         0.738   6140
# 2             0.262         0.738   6793
# 3             0.262         0.738   6608
# 4             0.262         0.738   5115
# ..              ...           ...    ...
# 139           0.216         0.784  11014
# 140           0.216         0.784  11050
# 141           0.216         0.784  12719
# 142           0.216         0.784   9889
# 143           0.216         0.784  12981
#
# [144 rows x 15 columns]

# %%
base_cost = 80_000_000

# Base fixed ratio from automation, plus random variation per period
base_fixed_ratio = 0.5 + 0.15 * pp["AUTOMATION_INDEX"]
random_variation = np.random.uniform(-0.10, 0.10, len(pp))  # ±10% noise
pp["FIXED"] = base_fixed_ratio + random_variation
pp['VARIABLE'] = 1 - pp["FIXED"]

pp["DM_RATIO"] = np.random.uniform(0.55, 0.65, len(pp)) + pp["DM_BIAS"]
pp["DL_RATIO"] = np.random.uniform(0.20, 0.30, len(pp)) + pp["DL_BIAS"]
pp["OH_RATIO"] = 1 - pp["DM_RATIO"] - pp["DL_RATIO"]

# Cost with both realistic (automation-driven) and stochastic components
pp["COST"] = base_cost * pp["SCALE"] * (pp["VARIABLE"] * pp["ACTIVITY_INDEX"] + pp["FIXED"])
pp['RM'] = pp["COST"] * pp["DM_RATIO"] * pp["RM_RATIO"]
pp['PM'] = pp["COST"] * pp["DM_RATIO"] * pp["PM_RATIO"]
pp['DL'] = pp["COST"] * pp["DL_RATIO"]
pp['OH_FIX'] = pp["COST"] * pp["OH_RATIO"] * pp["OH_FIXED_RATIO"]
pp['OH_VAR'] = pp["COST"] * pp["OH_RATIO"] * pp["OH_VAR_RATIO"]

pp.head(5).style.format({"COST": "{:,.2f}", "RM": "{:,.2f}", "PM": "{:,.2f}", "DL": "{:,.2f}", "OH_FIX": "{:,.2f}", "OH_VAR": "{:,.2f}"})
# Out:
# <style type="text/css">
# </style>
# <table id="T_29b7e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_29b7e_level0_col0" class="col_heading level0 col0" >PERIOD</th>
#       <th id="T_29b7e_level0_col1" class="col_heading level0 col1" >PLANT</th>
#       <th id="T_29b7e_level0_col2" class="col_heading level0 col2" >ACTIVITY_INDEX</th>
#       <th id="T_29b7e_level0_col3" class="col_heading level0 col3" >SCALE</th>
#       <th id="T_29b7e_level0_col4" class="col_heading level0 col4" >AUTOMATION_INDEX</th>
#       <th id="T_29b7e_level0_col5" class="col_heading level0 col5" >DM_BIAS</th>
#       <th id="T_29b7e_level0_col6" class="col_heading level0 col6" >DL_BIAS</th>
#       <th id="T_29b7e_level0_col7" class="col_heading level0 col7" >CC_COUNT</th>
#       <th id="T_29b7e_level0_col8" class="col_heading level0 col8" >PROD_CC_RATIO</th>
#       <th id="T_29b7e_level0_col9" class="col_heading level0 col9" >PROD_VOLATILITY</th>
#       <th id="T_29b7e_level0_col10" class="col_heading level0 col10" >RM_RATIO</th>
#       <th id="T_29b7e_level0_col11" class="col_heading level0 col11" >PM_RATIO</th>
#       <th id="T_29b7e_level0_col12" class="col_heading level0 col12" >OH_FIXED_RATIO</th>
#       <th id="T_29b7e_level0_col13" class="col_heading level0 col13" >OH_VAR_RATIO</th>
#       <th id="T_29b7e_level0_col14" class="col_heading level0 col14" >QTY</th>
#       <th id="T_29b7e_level0_col15" class="col_heading level0 col15" >FIXED</th>
#       <th id="T_29b7e_level0_col16" class="col_heading level0 col16" >VARIABLE</th>
#       <th id="T_29b7e_level0_col17" class="col_heading level0 col17" >DM_RATIO</th>
#       <th id="T_29b7e_level0_col18" class="col_heading level0 col18" >DL_RATIO</th>
#       <th id="T_29b7e_level0_col19" class="col_heading level0 col19" >OH_RATIO</th>
#       <th id="T_29b7e_level0_col20" class="col_heading level0 col20" >COST</th>
#       <th id="T_29b7e_level0_col21" class="col_heading level0 col21" >RM</th>
#       <th id="T_29b7e_level0_col22" class="col_heading level0 col22" >PM</th>
#       <th id="T_29b7e_level0_col23" class="col_heading level0 col23" >DL</th>
#       <th id="T_29b7e_level0_col24" class="col_heading level0 col24" >OH_FIX</th>
#       <th id="T_29b7e_level0_col25" class="col_heading level0 col25" >OH_VAR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_29b7e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_29b7e_row0_col0" class="data row0 col0" >2024-01</td>
#       <td id="T_29b7e_row0_col1" class="data row0 col1" >PLANT 1</td>
#       <td id="T_29b7e_row0_col2" class="data row0 col2" >1.079289</td>
#       <td id="T_29b7e_row0_col3" class="data row0 col3" >0.622000</td>
#       <td id="T_29b7e_row0_col4" class="data row0 col4" >-0.584000</td>
#       <td id="T_29b7e_row0_col5" class="data row0 col5" >-0.018000</td>
#       <td id="T_29b7e_row0_col6" class="data row0 col6" >0.018000</td>
#       <td id="T_29b7e_row0_col7" class="data row0 col7" >4</td>
#       <td id="T_29b7e_row0_col8" class="data row0 col8" >0.850000</td>
#       <td id="T_29b7e_row0_col9" class="data row0 col9" >0.077000</td>
#       <td id="T_29b7e_row0_col10" class="data row0 col10" >0.729000</td>
#       <td id="T_29b7e_row0_col11" class="data row0 col11" >0.271000</td>
#       <td id="T_29b7e_row0_col12" class="data row0 col12" >0.262000</td>
#       <td id="T_29b7e_row0_col13" class="data row0 col13" >0.738000</td>
#       <td id="T_29b7e_row0_col14" class="data row0 col14" >6665</td>
#       <td id="T_29b7e_row0_col15" class="data row0 col15" >0.479347</td>
#       <td id="T_29b7e_row0_col16" class="data row0 col16" >0.520653</td>
#       <td id="T_29b7e_row0_col17" class="data row0 col17" >0.625850</td>
#       <td id="T_29b7e_row0_col18" class="data row0 col18" >0.234245</td>
#       <td id="T_29b7e_row0_col19" class="data row0 col19" >0.139905</td>
#       <td id="T_29b7e_row0_col20" class="data row0 col20" >51,814,186.87</td>
#       <td id="T_29b7e_row0_col21" class="data row0 col21" >23,639,953.36</td>
#       <td id="T_29b7e_row0_col22" class="data row0 col22" >8,787,966.20</td>
#       <td id="T_29b7e_row0_col23" class="data row0 col23" >12,137,204.46</td>
#       <td id="T_29b7e_row0_col24" class="data row0 col24" >1,899,254.47</td>
#       <td id="T_29b7e_row0_col25" class="data row0 col25" >5,349,808.38</td>
#     </tr>
#     <tr>
#       <th id="T_29b7e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_29b7e_row1_col0" class="data row1 col0" >2024-02</td>
#       <td id="T_29b7e_row1_col1" class="data row1 col1" >PLANT 1</td>
#       <td id="T_29b7e_row1_col2" class="data row1 col2" >0.891325</td>
#       <td id="T_29b7e_row1_col3" class="data row1 col3" >0.622000</td>
#       <td id="T_29b7e_row1_col4" class="data row1 col4" >-0.584000</td>
#       <td id="T_29b7e_row1_col5" class="data row1 col5" >-0.018000</td>
#       <td id="T_29b7e_row1_col6" class="data row1 col6" >0.018000</td>
#       <td id="T_29b7e_row1_col7" class="data row1 col7" >4</td>
#       <td id="T_29b7e_row1_col8" class="data row1 col8" >0.850000</td>
#       <td id="T_29b7e_row1_col9" class="data row1 col9" >0.077000</td>
#       <td id="T_29b7e_row1_col10" class="data row1 col10" >0.729000</td>
#       <td id="T_29b7e_row1_col11" class="data row1 col11" >0.271000</td>
#       <td id="T_29b7e_row1_col12" class="data row1 col12" >0.262000</td>
#       <td id="T_29b7e_row1_col13" class="data row1 col13" >0.738000</td>
#       <td id="T_29b7e_row1_col14" class="data row1 col14" >6140</td>
#       <td id="T_29b7e_row1_col15" class="data row1 col15" >0.368149</td>
#       <td id="T_29b7e_row1_col16" class="data row1 col16" >0.631851</td>
#       <td id="T_29b7e_row1_col17" class="data row1 col17" >0.630862</td>
#       <td id="T_29b7e_row1_col18" class="data row1 col18" >0.276178</td>
#       <td id="T_29b7e_row1_col19" class="data row1 col19" >0.092960</td>
#       <td id="T_29b7e_row1_col20" class="data row1 col20" >46,343,159.51</td>
#       <td id="T_29b7e_row1_col21" class="data row1 col21" >21,313,148.40</td>
#       <td id="T_29b7e_row1_col22" class="data row1 col22" >7,922,994.81</td>
#       <td id="T_29b7e_row1_col23" class="data row1 col23" >12,798,954.22</td>
#       <td id="T_29b7e_row1_col24" class="data row1 col24" >1,128,712.26</td>
#       <td id="T_29b7e_row1_col25" class="data row1 col25" >3,179,349.81</td>
#     </tr>
#     <tr>
#       <th id="T_29b7e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_29b7e_row2_col0" class="data row2 col0" >2024-03</td>
#       <td id="T_29b7e_row2_col1" class="data row2 col1" >PLANT 1</td>
#       <td id="T_29b7e_row2_col2" class="data row2 col2" >1.085186</td>
#       <td id="T_29b7e_row2_col3" class="data row2 col3" >0.622000</td>
#       <td id="T_29b7e_row2_col4" class="data row2 col4" >-0.584000</td>
#       <td id="T_29b7e_row2_col5" class="data row2 col5" >-0.018000</td>
#       <td id="T_29b7e_row2_col6" class="data row2 col6" >0.018000</td>
#       <td id="T_29b7e_row2_col7" class="data row2 col7" >4</td>
#       <td id="T_29b7e_row2_col8" class="data row2 col8" >0.850000</td>
#       <td id="T_29b7e_row2_col9" class="data row2 col9" >0.077000</td>
#       <td id="T_29b7e_row2_col10" class="data row2 col10" >0.729000</td>
#       <td id="T_29b7e_row2_col11" class="data row2 col11" >0.271000</td>
#       <td id="T_29b7e_row2_col12" class="data row2 col12" >0.262000</td>
#       <td id="T_29b7e_row2_col13" class="data row2 col13" >0.738000</td>
#       <td id="T_29b7e_row2_col14" class="data row2 col14" >6793</td>
#       <td id="T_29b7e_row2_col15" class="data row2 col15" >0.437979</td>
#       <td id="T_29b7e_row2_col16" class="data row2 col16" >0.562021</td>
#       <td id="T_29b7e_row2_col17" class="data row2 col17" >0.572521</td>
#       <td id="T_29b7e_row2_col18" class="data row2 col18" >0.249445</td>
#       <td id="T_29b7e_row2_col19" class="data row2 col19" >0.178034</td>
#       <td id="T_29b7e_row2_col20" class="data row2 col20" >52,142,327.13</td>
#       <td id="T_29b7e_row2_col21" class="data row2 col21" >21,762,530.37</td>
#       <td id="T_29b7e_row2_col22" class="data row2

# %%
BP_plant = pp[[
    "PERIOD", "PLANT", "QTY", "COST", "RM", "PM", "DL", "OH_FIX", "OH_VAR"
]].groupby(["PERIOD", "PLANT"]).agg({
    "QTY": "sum",
    "COST": "sum",
    "RM": "sum",
    "PM": "sum",
    "DL": "sum",
    "OH_FIX": "sum",
    "OH_VAR": "sum",
})

BP_plant.head(5).style.format({"COST": "{:,.2f}", "RM": "{:,.2f}", "PM": "{:,.2f}", "DL": "{:,.2f}", "OH_FIX": "{:,.2f}", "OH_VAR": "{:,.2f}"})
# Out:
# <style type="text/css">
# </style>
# <table id="T_10410">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_10410_level0_col0" class="col_heading level0 col0" >QTY</th>
#       <th id="T_10410_level0_col1" class="col_heading level0 col1" >COST</th>
#       <th id="T_10410_level0_col2" class="col_heading level0 col2" >RM</th>
#       <th id="T_10410_level0_col3" class="col_heading level0 col3" >PM</th>
#       <th id="T_10410_level0_col4" class="col_heading level0 col4" >DL</th>
#       <th id="T_10410_level0_col5" class="col_heading level0 col5" >OH_FIX</th>
#       <th id="T_10410_level0_col6" class="col_heading level0 col6" >OH_VAR</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >PERIOD</th>
#       <th class="index_name level1" >PLANT</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_10410_level0_row0" class="row_heading level0 row0" rowspan="5">2024-01</th>
#       <th id="T_10410_level1_row0" class="row_heading level1 row0" >PLANT 1</th>
#       <td id="T_10410_row0_col0" class="data row0 col0" >6665</td>
#       <td id="T_10410_row0_col1" class="data row0 col1" >51,814,186.87</td>
#       <td id="T_10410_row0_col2" class="data row0 col2" >23,639,953.36</td>
#       <td id="T_10410_row0_col3" class="data row0 col3" >8,787,966.20</td>
#       <td id="T_10410_row0_col4" class="data row0 col4" >12,137,204.46</td>
#       <td id="T_10410_row0_col5" class="data row0 col5" >1,899,254.47</td>
#       <td id="T_10410_row0_col6" class="data row0 col6" >5,349,808.38</td>
#     </tr>
#     <tr>
#       <th id="T_10410_level1_row1" class="row_heading level1 row1" >PLANT 2</th>
#       <td id="T_10410_row1_col0" class="data row1 col0" >12157</td>
#       <td id="T_10410_row1_col1" class="data row1 col1" >93,679,677.78</td>
#       <td id="T_10410_row1_col2" class="data row1 col2" >42,552,768.46</td>
#       <td id="T_10410_row1_col3" class="data row1 col3" >15,263,493.03</td>
#       <td id="T_10410_row1_col4" class="data row1 col4" >28,052,983.62</td>
#       <td id="T_10410_row1_col5" class="data row1 col5" >1,819,830.81</td>
#       <td id="T_10410_row1_col6" class="data row1 col6" >5,990,601.85</td>
#     </tr>
#     <tr>
#       <th id="T_10410_level1_row2" class="row_heading level1 row2" >PLANT 3</th>
#       <td id="T_10410_row2_col0" class="data row2 col0" >10582</td>
#       <td id="T_10410_row2_col1" class="data row2 col1" >76,795,298.80</td>
#       <td id="T_10410_row2_col2" class="data row2 col2" >34,530,950.26</td>
#       <td id="T_10410_row2_col3" class="data row2 col3" >10,844,805.66</td>
#       <td id="T_10410_row2_col4" class="data row2 col4" >16,182,944.73</td>
#       <td id="T_10410_row2_col5" class="data row2 col5" >4,936,657.80</td>
#       <td id="T_10410_row2_col6" class="data row2 col6" >10,299,940.34</td>
#     </tr>
#     <tr>
#       <th id="T_10410_level1_row3" class="row_heading level1 row3" >PLANT 4</th>
#       <td id="T_10410_row3_col0" class="data row3 col0" >14963</td>
#       <td id="T_10410_row3_col1" class="data row3 col1" >104,757,273.33</td>
#       <td id="T_10410_row3_col2" class="data row3 col2" >50,728,147.51</td>
#       <td id="T_10410_row3_col3" class="data row3 col3" >12,920,720.13</td>
#       <td id="T_10410_row3_col4" class="data row3 col4" >26,511,433.29</td>
#       <td id="T_10410_row3_col5" class="data row3 col5" >5,926,370.79</td>
#       <td id="T_10410_row3_col6" class="data row3 col6" >8,670,601.60</td>
#     </tr>
#     <tr>
#       <th id="T_10410_level1_row4" class="row_heading level1 row4" >PLANT 5</th>
#       <td id="T_10410_row4_col0" class="data row4 col0" >8270</td>
#       <td id="T_10410_row4_col1" class="data row4 col1" >75,043,728.11</td>
#       <td id="T_10410_row4_col2" class="data row4 col2" >33,169,816.71</td>
#       <td id="T_10410_row4_col3" class="data row4 col3" >12,963,447.14</td>
#       <td id="T_10410_row4_col4" class="data row4 col4" >21,855,851.14</td>
#       <td id="T_10410_row4_col5" class="data row4 col5" >1,453,250.30</td>
#       <td id="T_10410_row4_col6" class="data row4 col6" >5,601,362.81</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### CC Breakdown

# %%
alloc_map = pd.DataFrame({
    "RM": {"Production": 1.0, "Supporting": 0.0},
    "PM": {"Production": 1.0, "Supporting": 0.0},
    "DL": {"Production": 0.7, "Supporting": 0.3},
    "OH_FIX": {"Production": 0.6, "Supporting": 0.4},
    "OH_VAR": {"Production": 0.5, "Supporting": 0.5},
})

alloc_map
# Out:
#              RM   PM   DL  OH_FIX  OH_VAR
# Production  1.0  1.0  0.7     0.6     0.5
# Supporting  0.0  0.0  0.3     0.4     0.5

# %%
# Merge once
BP = df.merge(
    BP_plant,
    on=['PERIOD', 'PLANT'],
    how='left',
    suffixes=('', '_PLANT')
)

# QTY
mask_prod = BP['CAT_CC'] == 'Production'
BP.loc[~mask_prod, 'QTY'] = 0
BP.loc[mask_prod, 'QTY'] = BP.loc[mask_prod, 'QTY_PLANT'] * BP.loc[mask_prod, 'QTY']

# Cost allocation (fully vectorized, no apply, no melt)
for ce in cost_elements['COST_ELEMENT']:
    BP[ce] = (
        BP[ce] *
        BP[f"{ce}_PLANT"] *
        BP['CAT_CC'].map(alloc_map[ce])
    )

# --- DROP helper columns (important part) ---
cols_to_drop = [col for col in BP.columns if col.endswith('_PLANT')]
BP.drop(columns=cols_to_drop, inplace=True)

BP.head(5).style.format({"COST": "{:,.2f}", "RM": "{:,.2f}", "PM": "{:,.2f}", "DL": "{:,.2f}", "OH_FIX": "{:,.2f}", "OH_VAR": "{:,.2f}"})
# Out:
# <style type="text/css">
# </style>
# <table id="T_ca791">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ca791_level0_col0" class="col_heading level0 col0" >PLANT</th>
#       <th id="T_ca791_level0_col1" class="col_heading level0 col1" >COST_CENTER</th>
#       <th id="T_ca791_level0_col2" class="col_heading level0 col2" >CAT_CC</th>
#       <th id="T_ca791_level0_col3" class="col_heading level0 col3" >PERIOD</th>
#       <th id="T_ca791_level0_col4" class="col_heading level0 col4" >RM</th>
#       <th id="T_ca791_level0_col5" class="col_heading level0 col5" >PM</th>
#       <th id="T_ca791_level0_col6" class="col_heading level0 col6" >DL</th>
#       <th id="T_ca791_level0_col7" class="col_heading level0 col7" >OH_FIX</th>
#       <th id="T_ca791_level0_col8" class="col_heading level0 col8" >OH_VAR</th>
#       <th id="T_ca791_level0_col9" class="col_heading level0 col9" >QTY</th>
#       <th id="T_ca791_level0_col10" class="col_heading level0 col10" >COST</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ca791_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ca791_row0_col0" class="data row0 col0" >PLANT 1</td>
#       <td id="T_ca791_row0_col1" class="data row0 col1" >CC001P01</td>
#       <td id="T_ca791_row0_col2" class="data row0 col2" >Production</td>
#       <td id="T_ca791_row0_col3" class="data row0 col3" >2024-01</td>
#       <td id="T_ca791_row0_col4" class="data row0 col4" >6,907,105.04</td>
#       <td id="T_ca791_row0_col5" class="data row0 col5" >3,421,694.03</td>
#       <td id="T_ca791_row0_col6" class="data row0 col6" >2,519,450.76</td>
#       <td id="T_ca791_row0_col7" class="data row0 col7" >306,011.24</td>
#       <td id="T_ca791_row0_col8" class="data row0 col8" >1,016,892.84</td>
#       <td id="T_ca791_row0_col9" class="data row0 col9" >2271.234085</td>
#       <td id="T_ca791_row0_col10" class="data row0 col10" >51,814,186.87</td>
#     </tr>
#     <tr>
#       <th id="T_ca791_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ca791_row1_col0" class="data row1 col0" >PLANT 1</td>
#       <td id="T_ca791_row1_col1" class="data row1 col1" >CC001P01</td>
#       <td id="T_ca791_row1_col2" class="data row1 col2" >Production</td>
#       <td id="T_ca791_row1_col3" class="data row1 col3" >2024-02</td>
#       <td id="T_ca791_row1_col4" class="data row1 col4" >6,752,730.79</td>
#       <td id="T_ca791_row1_col5" class="data row1 col5" >2,512,636.71</td>
#       <td id="T_ca791_row1_col6" class="data row1 col6" >3,149,253.62</td>
#       <td id="T_ca791_row1_col7" class="data row1 col7" >213,951.40</td>
#       <td id="T_ca791_row1_col8" class="data row1 col8" >567,399.52</td>
#       <td id="T_ca791_row1_col9" class="data row1 col9" >1946.276314</td>
#       <td id="T_ca791_row1_col10" class="data row1 col10" >46,343,159.51</td>
#     </tr>
#     <tr>
#       <th id="T_ca791_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ca791_row2_col0" class="data row2 col0" >PLANT 1</td>
#       <td id="T_ca791_row2_col1" class="data row2 col1" >CC001P01</td>
#       <td id="T_ca791_row2_col2" class="data row2 col2" >Production</td>
#       <td id="T_ca791_row2_col3" class="data row2 col3" >2024-03</td>
#       <td id="T_ca791_row2_col4" class="data row2 col4" >6,882,020.92</td>
#       <td id="T_ca791_row2_col5" class="data row2 col5" >2,958,822.55</td>
#       <td id="T_ca791_row2_col6" class="data row2 col6" >2,636,927.85</td>
#       <td id="T_ca791_row2_col7" class="data row2 col7" >417,405.69</td>
#       <td id="T_ca791_row2_col8" class="data row2 col8" >1,241,900.78</td>
#       <td id="T_ca791_row2_col9" class="data row2 col9" >2316.306411</td>
#       <td id="T_ca791_row2_col10" class="data row2 col10" >52,142,327.13</td>
#     </tr>
#     <tr>
#       <th id="T_ca791_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ca791_row3_col0" class="data row3 col0" >PLANT 1</td>
#       <td id="T_ca791_row3_col1" class="data row3 col1" >CC001P01</td>
#       <td id="T_ca791_row3_col2" class="data row3 col2" >Production</td>
#       <td id="T_ca791_row3_col3" class="data row3 col3" >2024-04</td>
#       <td id="T_ca791_row3_col4" class="data row3 col4" >6,748,522.60</td>
#       <td id="T_ca791_row3_col5" class="data row3 col5" >2,885,315.74</td>
#       <td id="T_ca791_row3_col6" class="data row3 col6" >3,258,591.86</td>
#       <td id="T_ca791_row3_col7" class="data row3 col7" >404,243.34</td>
#       <td id="T_ca791_row3_col8" class="data row3 col8" >977,078.16</td>
#       <td id="T_ca791_row3_col9" class="data row3 col9" >2139.550361</td>
#       <td id="T_ca791_row3_col10" class="data row3 col10" >52,436,690.10</td>
#     </tr>
#     <tr>
#       <th id="T_ca791_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ca791_row4_col0" class="data row4 col0" >PLANT 1</td>
#       <td id="T_ca791_row4_col1" class="data row4 col1" >CC001P01</td>
#       <td id="T_ca791_row4_col2" class="data row4 col2" >Production</td>
#       <td id="T_ca791_row4_col3" class="data row4 col3" >2024-05</td>
#       <td id="T_ca791_row4_col4" class="data row4 col4" >5,171,938.00</td>
#       <td id="T_ca791_row4_col5" class="data row4 col5" >2,498,998.21</td>
#       <td id="T_ca791_row4_col6" class="data row4 col6" >2,587,029.89</td>
#       <td id="T_ca791_row4_col7" class="data row4 col7" >340,209.85</td>
#       <td id="T_ca791_row4_col8" class="data row4 col8" >1,031,957.12</td>
#       <td id="T_ca791_row4_col9" class="data row4 col9" >1507.749535</td>
#       <td id="T_ca791_row4_col10" class="data row4 col10" >47,073,614.06</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### FG Breakdown

# %%
BP_QTY = BP.loc[BP['CAT_CC'] == 'Production', ['PERIOD', 'PLANT', 'COST_CENTER', 'QTY']].copy()

n = len(BP_QTY)
m = len(goods)
mask = np.random.randint(0, 8, size=(n, m)) != 0
rand_float = np.random.uniform(2, 6, size=(n, m))

BP_QTY[goods] = np.where(mask, rand_float, 0)
BP_QTY = pd.melt(BP_QTY, id_vars=['PERIOD', 'PLANT', 'COST_CENTER', 'QTY'], value_vars=goods, var_name='FG', value_name='QTY_ALLOC')
BP_QTY['QTY'] = BP_QTY['QTY_ALLOC'] / BP_QTY.groupby(['PERIOD', 'PLANT', 'COST_CENTER'])['QTY_ALLOC'].transform('sum') * BP_QTY['QTY']
BP_QTY.drop(columns=['QTY_ALLOC'], inplace=True)

BP_QTY.head(5)
# Out:
#     PERIOD    PLANT COST_CENTER         QTY    FG
# 0  2024-01  PLANT 1    CC001P01  402.652611  FG01
# 1  2024-02  PLANT 1    CC001P01  436.939367  FG01
# 2  2024-03  PLANT 1    CC001P01  563.416699  FG01
# 3  2024-04  PLANT 1    CC001P01  369.323121  FG01
# 4  2024-05  PLANT 1    CC001P01  327.748144  FG01

# %%
BP_QTY.groupby(['PERIOD', 'PLANT', 'COST_CENTER']).agg({'QTY': 'sum'})
# Out:
#                                      QTY
# PERIOD  PLANT   COST_CENTER
# 2024-01 PLANT 1 CC001P01     2271.234085
#                 CC001P02     2114.780520
#                 CC001P03     2278.985395
#         PLANT 2 CC002P01     2453.322705
#                 CC002P02     2706.012697
# ...                                  ...
# 2025-12 PLANT 6 CC006P02     2613.687314
#                 CC006P03     2002.551373
#                 CC006P04     2060.331990
#                 CC006P05     1969.840001
#                 CC006P06     2382.139774
#
# [840 rows x 1 columns]

# %%
pd.melt(
    BP.groupby(['PERIOD', 'PLANT']).agg({ce: 'sum' for ce in cost_elements['COST_ELEMENT']}).reset_index(),
    id_vars=['PERIOD', 'PLANT'],
    value_vars=cost_elements['COST_ELEMENT'].tolist(),
    var_name='COST_ELEMENT',
    value_name='COST'
).groupby(['PERIOD', 'PLANT']).agg({'COST': 'sum'}).head(5).style.format({"COST": "{:,.2f}"})
# Out:
# <style type="text/css">
# </style>
# <table id="T_002d4">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_002d4_level0_col0" class="col_heading level0 col0" >COST</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >PERIOD</th>
#       <th class="index_name level1" >PLANT</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_002d4_level0_row0" class="row_heading level0 row0" rowspan="5">2024-01</th>
#       <th id="T_002d4_level1_row0" class="row_heading level1 row0" >PLANT 1</th>
#       <td id="T_002d4_row0_col0" class="data row0 col0" >51,814,186.87</td>
#     </tr>
#     <tr>
#       <th id="T_002d4_level1_row1" class="row_heading level1 row1" >PLANT 2</th>
#       <td id="T_002d4_row1_col0" class="data row1 col0" >93,679,677.78</td>
#     </tr>
#     <tr>
#       <th id="T_002d4_level1_row2" class="row_heading level1 row2" >PLANT 3</th>
#       <td id="T_002d4_row2_col0" class="data row2 col0" >76,795,298.80</td>
#     </tr>
#     <tr>
#       <th id="T_002d4_level1_row3" class="row_heading level1 row3" >PLANT 4</th>
#       <td id="T_002d4_row3_col0" class="data row3 col0" >104,757,273.33</td>
#     </tr>
#     <tr>
#       <th id="T_002d4_level1_row4" class="row_heading level1 row4" >PLANT 5</th>
#       <td id="T_002d4_row4_col0" class="data row4 col0" >75,043,728.11</td>
#     </tr>
#   </tbody>
# </table>

# %%
BP.drop(columns=['COST'], inplace=True)
BP = pd.melt(
    BP, 
    id_vars=['PERIOD', 'PLANT', 'COST_CENTER', 'CAT_CC'], 
    value_vars=cost_elements['COST_ELEMENT'].tolist(), 
    var_name='COST_ELEMENT', 
    value_name='COST'
)

BP.head(10).style.format({"COST": "{:,.2f}"})
# Out:
# <style type="text/css">
# </style>
# <table id="T_f87cf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f87cf_level0_col0" class="col_heading level0 col0" >PERIOD</th>
#       <th id="T_f87cf_level0_col1" class="col_heading level0 col1" >PLANT</th>
#       <th id="T_f87cf_level0_col2" class="col_heading level0 col2" >COST_CENTER</th>
#       <th id="T_f87cf_level0_col3" class="col_heading level0 col3" >CAT_CC</th>
#       <th id="T_f87cf_level0_col4" class="col_heading level0 col4" >COST_ELEMENT</th>
#       <th id="T_f87cf_level0_col5" class="col_heading level0 col5" >COST</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f87cf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f87cf_row0_col0" class="data row0 col0" >2024-01</td>
#       <td id="T_f87cf_row0_col1" class="data row0 col1" >PLANT 1</td>
#       <td id="T_f87cf_row0_col2" class="data row0 col2" >CC001P01</td>
#       <td id="T_f87cf_row0_col3" class="data row0 col3" >Production</td>
#       <td id="T_f87cf_row0_col4" class="data row0 col4" >RM</td>
#       <td id="T_f87cf_row0_col5" class="data row0 col5" >6,907,105.04</td>
#     </tr>
#     <tr>
#       <th id="T_f87cf_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f87cf_row1_col0" class="data row1 col0" >2024-02</td>
#       <td id="T_f87cf_row1_col1" class="data row1 col1" >PLANT 1</td>
#       <td id="T_f87cf_row1_col2" class="data row1 col2" >CC001P01</td>
#       <td id="T_f87cf_row1_col3" class="data row1 col3" >Production</td>
#       <td id="T_f87cf_row1_col4" class="data row1 col4" >RM</td>
#       <td id="T_f87cf_row1_col5" class="data row1 col5" >6,752,730.79</td>
#     </tr>
#     <tr>
#       <th id="T_f87cf_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f87cf_row2_col0" class="data row2 col0" >2024-03</td>
#       <td id="T_f87cf_row2_col1" class="data row2 col1" >PLANT 1</td>
#       <td id="T_f87cf_row2_col2" class="data row2 col2" >CC001P01</td>
#       <td id="T_f87cf_row2_col3" class="data row2 col3" >Production</td>
#       <td id="T_f87cf_row2_col4" class="data row2 col4" >RM</td>
#       <td id="T_f87cf_row2_col5" class="data row2 col5" >6,882,020.92</td>
#     </tr>
#     <tr>
#       <th id="T_f87cf_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f87cf_row3_col0" class="data row3 col0" >2024-04</td>
#       <td id="T_f87cf_row3_col1" class="data row3 col1" >PLANT 1</td>
#       <td id="T_f87cf_row3_col2" class="data row3 col2" >CC001P01</td>
#       <td id="T_f87cf_row3_col3" class="data row3 col3" >Production</td>
#       <td id="T_f87cf_row3_col4" class="data row3 col4" >RM</td>
#       <td id="T_f87cf_row3_col5" class="data row3 col5" >6,748,522.60</td>
#     </tr>
#     <tr>
#       <th id="T_f87cf_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f87cf_row4_col0" class="data row4 col0" >2024-05</td>
#       <td id="T_f87cf_row4_col1" class="data row4 col1" >PLANT 1</td>
#       <td id="T_f87cf_row4_col2" class="data row4 col2" >CC001P01</td>
#       <td id="T_f87cf_row4_col3" class="data row4 col3" >Production</td>
#       <td id="T_f87cf_row4_col4" class="data row4 col4" >RM</td>
#       <td id="T_f87cf_row4_col5" class="data row4 col5" >5,171,938.00</td>
#     </tr>
#     <tr>
#       <th id="T_f87cf_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f87cf_row5_col0" class="data row5 col0" >2024-06</td>
#       <td id="T_f87cf_row5_col1" class="data row5 col1" >PLANT 1</td>
#       <td id="T_f87cf_row5_col2" class="data row5 col2" >CC001P01</td>
#       <td id="T_f87cf_row5_col3" class="data row5 col3" >Production</td>
#       <td id="T_f87cf_row5_col4" class="data row5 col4" >RM</td>
#       <td id="T_f87cf_row5_col5" class="data row5 col5" >7,554,453.92</td>
#     </tr>
#     <tr>
#       <th id="T_f87cf_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f87cf_row6_col0" class="data row6 col0" >2024-07</td>
#       <td id="T_f87cf_row6_col1" class="data row6 col1" >PLANT 1</td>
#       <td id="T_f87cf_row6_col2" class="data row6 col2" >CC001P01</td>
#       <td id="T_f87cf_row6_col3" class="data row6 col3" >Production</td>
#       <td id="T_f87cf_row6_col4" class="data row6 col4" >RM</td>
#       <td id="T_f87cf_row6_col5" class="data row6 col5" >6,454,198.87</td>
#     </tr>
#     <tr>
#       <th id="T_f87cf_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f87cf_row7_col0" class="data row7 col0" >2024-08</td>
#       <td id="T_f87cf_row7_col1" class="data row7 col1" >PLANT 1</td>
#       <td id="T_f87cf_row7_col2" class="data row7 col2" >CC001P01</td>
#       <td id="T_f87cf_row7_col3" class="data row7 col3" >Production</td>
#       <td id="T_f87cf_row7_col4" class="data row7 col4" >RM</td>
#       <td id="T_f87cf_row7_col5" class="data row7 col5" >7,171,284.49</td>
#     </tr>
#     <tr>
#       <th id="T_f87cf_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f87cf_row8_col0" class="data row8 col0" >2024-09</td>
#       <td id="T_f87cf_row8_col1" class="data row8 col1" >PLANT 1</td>
#       <td id="T_f87cf_row8_col2" class="data row8 col2" >CC001P01</td>
#       <td id="T_f87cf_row8_col3" class="data row8 col3" >Production</td>
#       <td id="T_f87cf_row8_col4" class="data row8 col4" >RM</td>
#       <td id="T_f87cf_row8_col5" class="data row8 col5" >6,334,171.26</td>
#     </tr>
#     <tr>
#       <th id="T_f87cf_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f87cf_row9_col0" class="data row9 col0" >2024-10</td>
#       <td id="T_f87cf_row9_col1" class="data row9 col1" >PLANT 1</td>
#       <td id="T_f87cf_row9_col2" class="data row9 col2" >CC001P01</td>
#       <td id="T_f87cf_row9_col3" class="data row9 col3" >Production</td>
#       <td id="T_f87cf_row9_col4" class="data row9 col4" >RM</td>
#       <td id="T_f87cf_row9_col5" class="data row9 col5" >8,245,431.18</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### **2. Actual**

# %%
pa = df[["PERIOD", "PLANT"]].drop_duplicates()

pa["ACTIVITY_INDEX"] = np.clip(
    np.random.normal(1.0, 0.1, len(pa)),
    0.8, 1.2
)

pa = pa.merge(plant_df, on="PLANT")
pa
# Out:
#       PERIOD    PLANT  ACTIVITY_INDEX  SCALE  AUTOMATION_INDEX  DM_BIAS  \
# 0    2024-01  PLANT 1        0.933612  0.622            -0.584   -0.018
# 1    2024-02  PLANT 1        0.800000  0.622            -0.584   -0.018
# 2    2024-03  PLANT 1        1.057046  0.622            -0.584   -0.018
# 3    2024-04  PLANT 1        1.009865  0.622            -0.584   -0.018
# 4    2024-05  PLANT 1        1.012408  0.622            -0.584   -0.018
# ..       ...      ...             ...    ...               ...      ...
# 139  2025-08  PLANT 6        0.925853  1.029            -0.894   -0.027
# 140  2025-09  PLANT 6        0.990177  1.029            -0.894   -0.027
# 141  2025-10  PLANT 6        1.087926  1.029            -0.894   -0.027
# 142  2025-11  PLANT 6        0.854378  1.029            -0.894   -0.027
# 143  2025-12  PLANT 6        0.956533  1.029            -0.894   -0.027
#
#      DL_BIAS  CC_COUNT  PROD_CC_RATIO  PROD_VOLATILITY  RM_RATIO  PM_RATIO  \
# 0      0.018         4           0.85            0.077     0.729     0.271
# 1      0.018         4           0.85            0.077     0.729     0.271
# 2      0.018         4           0.85            0.077     0.729     0.271
# 3      0.018         4           0.85            0.077     0.729     0.271
# 4      0.018         4           0.85            0.077     0.729     0.271
# ..       ...       ...            ...              ...       ...       ...
# 139    0.027         8           0.85            0.125     0.726     0.274
# 140    0.027         8           0.85            0.125     0.726     0.274
# 141    0.027         8           0.85            0.125     0.726     0.274
# 142    0.027         8           0.85            0.125     0.726     0.274
# 143    0.027         8           0.85            0.125     0.726     0.274
#
#      OH_FIXED_RATIO  OH_VAR_RATIO
# 0             0.262         0.738
# 1             0.262         0.738
# 2             0.262         0.738
# 3             0.262         0.738
# 4             0.262         0.738
# ..              ...           ...
# 139           0.216         0.784
# 140           0.216         0.784
# 141           0.216         0.784
# 142           0.216         0.784
# 143           0.216         0.784
#
# [144 rows x 14 columns]

# %% [markdown]
# #### Plant Level

# %%
# base_qty = 10_000
# cv = 0.12  # Coefficient of variation (adjust based on your volatility assumptions)
# bound_pct = 0.30  # ±30% bounds

mean_qty = base_qty * pa["SCALE"] * pa["ACTIVITY_INDEX"]
pa["QTY"] = np.clip(
    np.random.normal(mean_qty, mean_qty * pa["PROD_VOLATILITY"]),
    mean_qty * (1 - bound_pct),
    mean_qty * (1 + bound_pct)
).astype(int)
# df = df.merge(pa, on=["PERIOD", "PLANT"])
# df
pa
# Out:
#       PERIOD    PLANT  ACTIVITY_INDEX  SCALE  AUTOMATION_INDEX  DM_BIAS  \
# 0    2024-01  PLANT 1        0.933612  0.622            -0.584   -0.018
# 1    2024-02  PLANT 1        0.800000  0.622            -0.584   -0.018
# 2    2024-03  PLANT 1        1.057046  0.622            -0.584   -0.018
# 3    2024-04  PLANT 1        1.009865  0.622            -0.584   -0.018
# 4    2024-05  PLANT 1        1.012408  0.622            -0.584   -0.018
# ..       ...      ...             ...    ...               ...      ...
# 139  2025-08  PLANT 6        0.925853  1.029            -0.894   -0.027
# 140  2025-09  PLANT 6        0.990177  1.029            -0.894   -0.027
# 141  2025-10  PLANT 6        1.087926  1.029            -0.894   -0.027
# 142  2025-11  PLANT 6        0.854378  1.029            -0.894   -0.027
# 143  2025-12  PLANT 6        0.956533  1.029            -0.894   -0.027
#
#      DL_BIAS  CC_COUNT  PROD_CC_RATIO  PROD_VOLATILITY  RM_RATIO  PM_RATIO  \
# 0      0.018         4           0.85            0.077     0.729     0.271
# 1      0.018         4           0.85            0.077     0.729     0.271
# 2      0.018         4           0.85            0.077     0.729     0.271
# 3      0.018         4           0.85            0.077     0.729     0.271
# 4      0.018         4           0.85            0.077     0.729     0.271
# ..       ...       ...            ...              ...       ...       ...
# 139    0.027         8           0.85            0.125     0.726     0.274
# 140    0.027         8           0.85            0.125     0.726     0.274
# 141    0.027         8           0.85            0.125     0.726     0.274
# 142    0.027         8           0.85            0.125     0.726     0.274
# 143    0.027         8           0.85            0.125     0.726     0.274
#
#      OH_FIXED_RATIO  OH_VAR_RATIO    QTY
# 0             0.262         0.738   5191
# 1             0.262         0.738   5119
# 2             0.262         0.738   7224
# 3             0.262         0.738   5794
# 4             0.262         0.738   6563
# ..              ...           ...    ...
# 139           0.216         0.784   8879
# 140           0.216         0.784   9632
# 141           0.216         0.784  12061
# 142           0.216         0.784   6946
# 143           0.216         0.784  10287
#
# [144 rows x 15 columns]

# %%
# base_cost = 80_000_000

# Base fixed ratio from automation, plus random variation per period
base_fixed_ratio = 0.5 + 0.15 * pa["AUTOMATION_INDEX"]
random_variation = np.random.uniform(-0.10, 0.10, len(pa))  # ±10% noise
pa["FIXED"] = base_fixed_ratio + random_variation
pa['VARIABLE'] = 1 - pa["FIXED"]

pa["DM_RATIO"] = np.random.uniform(0.55, 0.65, len(pa)) + pa["DM_BIAS"]
pa["DL_RATIO"] = np.random.uniform(0.20, 0.30, len(pa)) + pa["DL_BIAS"]
pa["OH_RATIO"] = 1 - pa["DM_RATIO"] - pa["DL_RATIO"]

# Cost with both realistic (automation-driven) and stochastic components
pa["COST"] = base_cost * pa["SCALE"] * (pa["VARIABLE"] * pa["ACTIVITY_INDEX"] + pa["FIXED"])
pa['RM'] = pa["COST"] * pa["DM_RATIO"] * pa["RM_RATIO"]
pa['PM'] = pa["COST"] * pa["DM_RATIO"] * pa["PM_RATIO"]
pa['DL'] = pa["COST"] * pa["DL_RATIO"]
pa['OH_FIX'] = pa["COST"] * pa["OH_RATIO"] * pa["OH_FIXED_RATIO"]
pa['OH_VAR'] = pa["COST"] * pa["OH_RATIO"] * pa["OH_VAR_RATIO"]

pa.head(5).style.format({"COST": "{:,.2f}", "RM": "{:,.2f}", "PM": "{:,.2f}", "DL": "{:,.2f}", "OH_FIX": "{:,.2f}", "OH_VAR": "{:,.2f}"})
# Out:
# <style type="text/css">
# </style>
# <table id="T_e47a8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e47a8_level0_col0" class="col_heading level0 col0" >PERIOD</th>
#       <th id="T_e47a8_level0_col1" class="col_heading level0 col1" >PLANT</th>
#       <th id="T_e47a8_level0_col2" class="col_heading level0 col2" >ACTIVITY_INDEX</th>
#       <th id="T_e47a8_level0_col3" class="col_heading level0 col3" >SCALE</th>
#       <th id="T_e47a8_level0_col4" class="col_heading level0 col4" >AUTOMATION_INDEX</th>
#       <th id="T_e47a8_level0_col5" class="col_heading level0 col5" >DM_BIAS</th>
#       <th id="T_e47a8_level0_col6" class="col_heading level0 col6" >DL_BIAS</th>
#       <th id="T_e47a8_level0_col7" class="col_heading level0 col7" >CC_COUNT</th>
#       <th id="T_e47a8_level0_col8" class="col_heading level0 col8" >PROD_CC_RATIO</th>
#       <th id="T_e47a8_level0_col9" class="col_heading level0 col9" >PROD_VOLATILITY</th>
#       <th id="T_e47a8_level0_col10" class="col_heading level0 col10" >RM_RATIO</th>
#       <th id="T_e47a8_level0_col11" class="col_heading level0 col11" >PM_RATIO</th>
#       <th id="T_e47a8_level0_col12" class="col_heading level0 col12" >OH_FIXED_RATIO</th>
#       <th id="T_e47a8_level0_col13" class="col_heading level0 col13" >OH_VAR_RATIO</th>
#       <th id="T_e47a8_level0_col14" class="col_heading level0 col14" >QTY</th>
#       <th id="T_e47a8_level0_col15" class="col_heading level0 col15" >FIXED</th>
#       <th id="T_e47a8_level0_col16" class="col_heading level0 col16" >VARIABLE</th>
#       <th id="T_e47a8_level0_col17" class="col_heading level0 col17" >DM_RATIO</th>
#       <th id="T_e47a8_level0_col18" class="col_heading level0 col18" >DL_RATIO</th>
#       <th id="T_e47a8_level0_col19" class="col_heading level0 col19" >OH_RATIO</th>
#       <th id="T_e47a8_level0_col20" class="col_heading level0 col20" >COST</th>
#       <th id="T_e47a8_level0_col21" class="col_heading level0 col21" >RM</th>
#       <th id="T_e47a8_level0_col22" class="col_heading level0 col22" >PM</th>
#       <th id="T_e47a8_level0_col23" class="col_heading level0 col23" >DL</th>
#       <th id="T_e47a8_level0_col24" class="col_heading level0 col24" >OH_FIX</th>
#       <th id="T_e47a8_level0_col25" class="col_heading level0 col25" >OH_VAR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e47a8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e47a8_row0_col0" class="data row0 col0" >2024-01</td>
#       <td id="T_e47a8_row0_col1" class="data row0 col1" >PLANT 1</td>
#       <td id="T_e47a8_row0_col2" class="data row0 col2" >0.933612</td>
#       <td id="T_e47a8_row0_col3" class="data row0 col3" >0.622000</td>
#       <td id="T_e47a8_row0_col4" class="data row0 col4" >-0.584000</td>
#       <td id="T_e47a8_row0_col5" class="data row0 col5" >-0.018000</td>
#       <td id="T_e47a8_row0_col6" class="data row0 col6" >0.018000</td>
#       <td id="T_e47a8_row0_col7" class="data row0 col7" >4</td>
#       <td id="T_e47a8_row0_col8" class="data row0 col8" >0.850000</td>
#       <td id="T_e47a8_row0_col9" class="data row0 col9" >0.077000</td>
#       <td id="T_e47a8_row0_col10" class="data row0 col10" >0.729000</td>
#       <td id="T_e47a8_row0_col11" class="data row0 col11" >0.271000</td>
#       <td id="T_e47a8_row0_col12" class="data row0 col12" >0.262000</td>
#       <td id="T_e47a8_row0_col13" class="data row0 col13" >0.738000</td>
#       <td id="T_e47a8_row0_col14" class="data row0 col14" >5191</td>
#       <td id="T_e47a8_row0_col15" class="data row0 col15" >0.351117</td>
#       <td id="T_e47a8_row0_col16" class="data row0 col16" >0.648883</td>
#       <td id="T_e47a8_row0_col17" class="data row0 col17" >0.587665</td>
#       <td id="T_e47a8_row0_col18" class="data row0 col18" >0.307646</td>
#       <td id="T_e47a8_row0_col19" class="data row0 col19" >0.104689</td>
#       <td id="T_e47a8_row0_col20" class="data row0 col20" >47,616,422.41</td>
#       <td id="T_e47a8_row0_col21" class="data row0 col21" >20,399,262.36</td>
#       <td id="T_e47a8_row0_col22" class="data row0 col22" >7,583,264.88</td>
#       <td id="T_e47a8_row0_col23" class="data row0 col23" >14,648,990.10</td>
#       <td id="T_e47a8_row0_col24" class="data row0 col24" >1,306,045.13</td>
#       <td id="T_e47a8_row0_col25" class="data row0 col25" >3,678,859.94</td>
#     </tr>
#     <tr>
#       <th id="T_e47a8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e47a8_row1_col0" class="data row1 col0" >2024-02</td>
#       <td id="T_e47a8_row1_col1" class="data row1 col1" >PLANT 1</td>
#       <td id="T_e47a8_row1_col2" class="data row1 col2" >0.800000</td>
#       <td id="T_e47a8_row1_col3" class="data row1 col3" >0.622000</td>
#       <td id="T_e47a8_row1_col4" class="data row1 col4" >-0.584000</td>
#       <td id="T_e47a8_row1_col5" class="data row1 col5" >-0.018000</td>
#       <td id="T_e47a8_row1_col6" class="data row1 col6" >0.018000</td>
#       <td id="T_e47a8_row1_col7" class="data row1 col7" >4</td>
#       <td id="T_e47a8_row1_col8" class="data row1 col8" >0.850000</td>
#       <td id="T_e47a8_row1_col9" class="data row1 col9" >0.077000</td>
#       <td id="T_e47a8_row1_col10" class="data row1 col10" >0.729000</td>
#       <td id="T_e47a8_row1_col11" class="data row1 col11" >0.271000</td>
#       <td id="T_e47a8_row1_col12" class="data row1 col12" >0.262000</td>
#       <td id="T_e47a8_row1_col13" class="data row1 col13" >0.738000</td>
#       <td id="T_e47a8_row1_col14" class="data row1 col14" >5119</td>
#       <td id="T_e47a8_row1_col15" class="data row1 col15" >0.332598</td>
#       <td id="T_e47a8_row1_col16" class="data row1 col16" >0.667402</td>
#       <td id="T_e47a8_row1_col17" class="data row1 col17" >0.590316</td>
#       <td id="T_e47a8_row1_col18" class="data row1 col18" >0.286356</td>
#       <td id="T_e47a8_row1_col19" class="data row1 col19" >0.123328</td>
#       <td id="T_e47a8_row1_col20" class="data row1 col20" >43,118,014.13</td>
#       <td id="T_e47a8_row1_col21" class="data row1 col21" >18,555,414.79</td>
#       <td id="T_e47a8_row1_col22" class="data row1 col22" >6,897,829.09</td>
#       <td id="T_e47a8_row1_col23" class="data row1 col23" >12,347,103.45</td>
#       <td id="T_e47a8_row1_col24" class="data row1 col24" >1,393,228.70</td>
#       <td id="T_e47a8_row1_col25" class="data row1 col25" >3,924,438.10</td>
#     </tr>
#     <tr>
#       <th id="T_e47a8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e47a8_row2_col0" class="data row2 col0" >2024-03</td>
#       <td id="T_e47a8_row2_col1" class="data row2 col1" >PLANT 1</td>
#       <td id="T_e47a8_row2_col2" class="data row2 col2" >1.057046</td>
#       <td id="T_e47a8_row2_col3" class="data row2 col3" >0.622000</td>
#       <td id="T_e47a8_row2_col4" class="data row2 col4" >-0.584000</td>
#       <td id="T_e47a8_row2_col5" class="data row2 col5" >-0.018000</td>
#       <td id="T_e47a8_row2_col6" class="data row2 col6" >0.018000</td>
#       <td id="T_e47a8_row2_col7" class="data row2 col7" >4</td>
#       <td id="T_e47a8_row2_col8" class="data row2 col8" >0.850000</td>
#       <td id="T_e47a8_row2_col9" class="data row2 col9" >0.077000</td>
#       <td id="T_e47a8_row2_col10" class="data row2 col10" >0.729000</td>
#       <td id="T_e47a8_row2_col11" class="data row2 col11" >0.271000</td>
#       <td id="T_e47a8_row2_col12" class="data row2 col12" >0.262000</td>
#       <td id="T_e47a8_row2_col13" class="data row2 col13" >0.738000</td>
#       <td id="T_e47a8_row2_col14" class="data row2 col14" >7224</td>
#       <td id="T_e47a8_row2_col15" class="data row2 col15" >0.431448</td>
#       <td id="T_e47a8_row2_col16" class="data row2 col16" >0.568552</td>
#       <td id="T_e47a8_row2_col17" class="data row2 col17" >0.605453</td>
#       <td id="T_e47a8_row2_col18" class="data row2 col18" >0.306025</td>
#       <td id="T_e47a8_row2_col19" class="data row2 col19" >0.088522</td>
#       <td id="T_e47a8_row2_col20" class="data row2 col20" >51,373,886.50</td>
#       <td id="T_e47a8_row2_col21" class="data row2 col21" >22,675,149.13</td>
#       <td id="T_e47a8_row2_col22" class="data row2

# %%
act_plant = pa[[
    "PERIOD", "PLANT", "QTY", "COST", "RM", "PM", "DL", "OH_FIX", "OH_VAR"
]].groupby(["PERIOD", "PLANT"]).agg({
    "QTY": "sum",
    "COST": "sum",
    "RM": "sum",
    "PM": "sum",
    "DL": "sum",
    "OH_FIX": "sum",
    "OH_VAR": "sum",
})

act_plant.head(5).style.format({"COST": "{:,.2f}", "RM": "{:,.2f}", "PM": "{:,.2f}", "DL": "{:,.2f}", "OH_FIX": "{:,.2f}", "OH_VAR": "{:,.2f}"})
# Out:
# <style type="text/css">
# </style>
# <table id="T_cb724">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cb724_level0_col0" class="col_heading level0 col0" >QTY</th>
#       <th id="T_cb724_level0_col1" class="col_heading level0 col1" >COST</th>
#       <th id="T_cb724_level0_col2" class="col_heading level0 col2" >RM</th>
#       <th id="T_cb724_level0_col3" class="col_heading level0 col3" >PM</th>
#       <th id="T_cb724_level0_col4" class="col_heading level0 col4" >DL</th>
#       <th id="T_cb724_level0_col5" class="col_heading level0 col5" >OH_FIX</th>
#       <th id="T_cb724_level0_col6" class="col_heading level0 col6" >OH_VAR</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >PERIOD</th>
#       <th class="index_name level1" >PLANT</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cb724_level0_row0" class="row_heading level0 row0" rowspan="5">2024-01</th>
#       <th id="T_cb724_level1_row0" class="row_heading level1 row0" >PLANT 1</th>
#       <td id="T_cb724_row0_col0" class="data row0 col0" >5191</td>
#       <td id="T_cb724_row0_col1" class="data row0 col1" >47,616,422.41</td>
#       <td id="T_cb724_row0_col2" class="data row0 col2" >20,399,262.36</td>
#       <td id="T_cb724_row0_col3" class="data row0 col3" >7,583,264.88</td>
#       <td id="T_cb724_row0_col4" class="data row0 col4" >14,648,990.10</td>
#       <td id="T_cb724_row0_col5" class="data row0 col5" >1,306,045.13</td>
#       <td id="T_cb724_row0_col6" class="data row0 col6" >3,678,859.94</td>
#     </tr>
#     <tr>
#       <th id="T_cb724_level1_row1" class="row_heading level1 row1" >PLANT 2</th>
#       <td id="T_cb724_row1_col0" class="data row1 col0" >12292</td>
#       <td id="T_cb724_row1_col1" class="data row1 col1" >99,001,103.20</td>
#       <td id="T_cb724_row1_col2" class="data row1 col2" >45,534,222.14</td>
#       <td id="T_cb724_row1_col3" class="data row1 col3" >16,332,927.51</td>
#       <td id="T_cb724_row1_col4" class="data row1 col4" >25,651,425.92</td>
#       <td id="T_cb724_row1_col5" class="data row1 col5" >2,675,428.94</td>
#       <td id="T_cb724_row1_col6" class="data row1 col6" >8,807,098.70</td>
#     </tr>
#     <tr>
#       <th id="T_cb724_level1_row2" class="row_heading level1 row2" >PLANT 3</th>
#       <td id="T_cb724_row2_col0" class="data row2 col0" >6592</td>
#       <td id="T_cb724_row2_col1" class="data row2 col1" >76,619,433.54</td>
#       <td id="T_cb724_row2_col2" class="data row2 col2" >32,411,539.28</td>
#       <td id="T_cb724_row2_col3" class="data row2 col3" >10,179,182.51</td>
#       <td id="T_cb724_row2_col4" class="data row2 col4" >19,059,150.79</td>
#       <td id="T_cb724_row2_col5" class="data row2 col5" >4,850,137.75</td>
#       <td id="T_cb724_row2_col6" class="data row2 col6" >10,119,423.22</td>
#     </tr>
#     <tr>
#       <th id="T_cb724_level1_row3" class="row_heading level1 row3" >PLANT 4</th>
#       <td id="T_cb724_row3_col0" class="data row3 col0" >16834</td>
#       <td id="T_cb724_row3_col1" class="data row3 col1" >113,746,254.34</td>
#       <td id="T_cb724_row3_col2" class="data row3 col2" >54,046,485.39</td>
#       <td id="T_cb724_row3_col3" class="data row3 col3" >13,765,917.86</td>
#       <td id="T_cb724_row3_col4" class="data row3 col4" >31,541,041.63</td>
#       <td id="T_cb724_row3_col5" class="data row3 col5" >5,843,480.64</td>
#       <td id="T_cb724_row3_col6" class="data row3 col6" >8,549,328.82</td>
#     </tr>
#     <tr>
#       <th id="T_cb724_level1_row4" class="row_heading level1 row4" >PLANT 5</th>
#       <td id="T_cb724_row4_col0" class="data row4 col0" >8941</td>
#       <td id="T_cb724_row4_col1" class="data row4 col1" >78,152,760.40</td>
#       <td id="T_cb724_row4_col2" class="data row4 col2" >31,667,778.17</td>
#       <td id="T_cb724_row4_col3" class="data row4 col3" >12,376,419.56</td>
#       <td id="T_cb724_row4_col4" class="data row4 col4" >19,437,470.20</td>
#       <td id="T_cb724_row4_col5" class="data row4 col5" >3,022,245.05</td>
#       <td id="T_cb724_row4_col6" class="data row4 col6" >11,648,847.42</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### CC Breakdown

# %%
# alloc_map = pd.DataFrame({
#     "RM": {"Production": 1.0, "Supporting": 0.0},
#     "PM": {"Production": 1.0, "Supporting": 0.0},
#     "DL": {"Production": 0.7, "Supporting": 0.3},
#     "OH_FIX": {"Production": 0.6, "Supporting": 0.4},
#     "OH_VAR": {"Production": 0.5, "Supporting": 0.5},
# })

# alloc_map

# %%
# Merge once
act = df.merge(
    act_plant,
    on=['PERIOD', 'PLANT'],
    how='left',
    suffixes=('', '_PLANT')
)

# QTY
mask_prod = act['CAT_CC'] == 'Production'
act.loc[~mask_prod, 'QTY'] = 0
act.loc[mask_prod, 'QTY'] = act.loc[mask_prod, 'QTY_PLANT'] * act.loc[mask_prod, 'QTY']

# Cost allocation (fully vectorized, no apply, no melt)
for ce in cost_elements['COST_ELEMENT']:
    act[ce] = (
        act[ce] *
        act[f"{ce}_PLANT"] *
        act['CAT_CC'].map(alloc_map[ce])
    )

# --- DROP helper columns (important part) ---
cols_to_drop = [col for col in act.columns if col.endswith('_PLANT')]
act.drop(columns=cols_to_drop, inplace=True)

act.head(5).style.format({"COST": "{:,.2f}", "RM": "{:,.2f}", "PM": "{:,.2f}", "DL": "{:,.2f}", "OH_FIX": "{:,.2f}", "OH_VAR": "{:,.2f}"})
# Out:
# <style type="text/css">
# </style>
# <table id="T_32061">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_32061_level0_col0" class="col_heading level0 col0" >PLANT</th>
#       <th id="T_32061_level0_col1" class="col_heading level0 col1" >COST_CENTER</th>
#       <th id="T_32061_level0_col2" class="col_heading level0 col2" >CAT_CC</th>
#       <th id="T_32061_level0_col3" class="col_heading level0 col3" >PERIOD</th>
#       <th id="T_32061_level0_col4" class="col_heading level0 col4" >RM</th>
#       <th id="T_32061_level0_col5" class="col_heading level0 col5" >PM</th>
#       <th id="T_32061_level0_col6" class="col_heading level0 col6" >DL</th>
#       <th id="T_32061_level0_col7" class="col_heading level0 col7" >OH_FIX</th>
#       <th id="T_32061_level0_col8" class="col_heading level0 col8" >OH_VAR</th>
#       <th id="T_32061_level0_col9" class="col_heading level0 col9" >QTY</th>
#       <th id="T_32061_level0_col10" class="col_heading level0 col10" >COST</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_32061_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_32061_row0_col0" class="data row0 col0" >PLANT 1</td>
#       <td id="T_32061_row0_col1" class="data row0 col1" >CC001P01</td>
#       <td id="T_32061_row0_col2" class="data row0 col2" >Production</td>
#       <td id="T_32061_row0_col3" class="data row0 col3" >2024-01</td>
#       <td id="T_32061_row0_col4" class="data row0 col4" >5,960,242.21</td>
#       <td id="T_32061_row0_col5" class="data row0 col5" >2,952,629.95</td>
#       <td id="T_32061_row0_col6" class="data row0 col6" >3,040,849.26</td>
#       <td id="T_32061_row0_col7" class="data row0 col7" >210,432.30</td>
#       <td id="T_32061_row0_col8" class="data row0 col8" >699,278.56</td>
#       <td id="T_32061_row0_col9" class="data row0 col9" >1768.938655</td>
#       <td id="T_32061_row0_col10" class="data row0 col10" >47,616,422.41</td>
#     </tr>
#     <tr>
#       <th id="T_32061_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_32061_row1_col0" class="data row1 col0" >PLANT 1</td>
#       <td id="T_32061_row1_col1" class="data row1 col1" >CC001P01</td>
#       <td id="T_32061_row1_col2" class="data row1 col2" >Production</td>
#       <td id="T_32061_row1_col3" class="data row1 col3" >2024-02</td>
#       <td id="T_32061_row1_col4" class="data row1 col4" >5,878,986.92</td>
#       <td id="T_32061_row1_col5" class="data row1 col5" >2,187,523.66</td>
#       <td id="T_32061_row1_col6" class="data row1 col6" >3,038,073.24</td>
#       <td id="T_32061_row1_col7" class="data row1 col7" >264,091.42</td>
#       <td id="T_32061_row1_col8" class="data row1 col8" >700,370.97</td>
#       <td id="T_32061_row1_col9" class="data row1 col9" >1622.636555</td>
#       <td id="T_32061_row1_col10" class="data row1 col10" >43,118,014.13</td>
#     </tr>
#     <tr>
#       <th id="T_32061_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_32061_row2_col0" class="data row2 col0" >PLANT 1</td>
#       <td id="T_32061_row2_col1" class="data row2 col1" >CC001P01</td>
#       <td id="T_32061_row2_col2" class="data row2 col2" >Production</td>
#       <td id="T_32061_row2_col3" class="data row2 col3" >2024-03</td>
#       <td id="T_32061_row2_col4" class="data row2 col4" >7,170,620.70</td>
#       <td id="T_32061_row2_col5" class="data row2 col5" >3,082,901.73</td>
#       <td id="T_32061_row2_col6" class="data row2 col6" >3,187,362.76</td>
#       <td id="T_32061_row2_col7" class="data row2 col7" >204,485.26</td>
#       <td id="T_32061_row2_col8" class="data row2 col8" >608,401.87</td>
#       <td id="T_32061_row2_col9" class="data row2 col9" >2463.270648</td>
#       <td id="T_32061_row2_col10" class="data row2 col10" >51,373,886.50</td>
#     </tr>
#     <tr>
#       <th id="T_32061_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_32061_row3_col0" class="data row3 col0" >PLANT 1</td>
#       <td id="T_32061_row3_col1" class="data row3 col1" >CC001P01</td>
#       <td id="T_32061_row3_col2" class="data row3 col2" >Production</td>
#       <td id="T_32061_row3_col3" class="data row3 col3" >2024-04</td>
#       <td id="T_32061_row3_col4" class="data row3 col4" >6,416,939.68</td>
#       <td id="T_32061_row3_col5" class="data row3 col5" >2,743,548.21</td>
#       <td id="T_32061_row3_col6" class="data row3 col6" >2,972,756.83</td>
#       <td id="T_32061_row3_col7" class="data row3 col7" >422,651.88</td>
#       <td id="T_32061_row3_col8" class="data row3 col8" >1,021,572.62</td>
#       <td id="T_32061_row3_col9" class="data row3 col9" >1875.991948</td>
#       <td id="T_32061_row3_col10" class="data row3 col10" >50,072,610.52</td>
#     </tr>
#     <tr>
#       <th id="T_32061_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_32061_row4_col0" class="data row4 col0" >PLANT 1</td>
#       <td id="T_32061_row4_col1" class="data row4 col1" >CC001P01</td>
#       <td id="T_32061_row4_col2" class="data row4 col2" >Production</td>
#       <td id="T_32061_row4_col3" class="data row4 col3" >2024-05</td>
#       <td id="T_32061_row4_col4" class="data row4 col4" >5,413,411.69</td>
#       <td id="T_32061_row4_col5" class="data row4 col5" >2,615,674.46</td>
#       <td id="T_32061_row4_col6" class="data row4 col6" >2,482,800.85</td>
#       <td id="T_32061_row4_col7" class="data row4 col7" >452,953.59</td>
#       <td id="T_32061_row4_col8" class="data row4 col8" >1,373,942.26</td>
#       <td id="T_32061_row4_col9" class="data row4 col9" >1934.576774</td>
#       <td id="T_32061_row4_col10" class="data row4 col10" >50,094,043.98</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### FG Breakdown

# %%
act_QTY = act.loc[act['CAT_CC'] == 'Production', ['PERIOD', 'PLANT', 'COST_CENTER', 'QTY']].copy()

n = len(act_QTY)
m = len(goods)
# mask = np.random.randint(0, 8, size=(n, m)) != 0
# rand_float = np.random.uniform(2, 6, size=(n, m))

act_QTY[goods] = np.where(mask, rand_float, 0)
act_QTY = pd.melt(act_QTY, id_vars=['PERIOD', 'PLANT', 'COST_CENTER', 'QTY'], value_vars=goods, var_name='FG', value_name='QTY_ALLOC')
act_QTY['QTY'] = act_QTY['QTY_ALLOC'] / act_QTY.groupby(['PERIOD', 'PLANT', 'COST_CENTER'])['QTY_ALLOC'].transform('sum') * act_QTY['QTY']
act_QTY.drop(columns=['QTY_ALLOC'], inplace=True)

act_QTY.head(5)
# Out:
#     PERIOD    PLANT COST_CENTER         QTY    FG
# 0  2024-01  PLANT 1    CC001P01  313.603856  FG01
# 1  2024-02  PLANT 1    CC001P01  364.282185  FG01
# 2  2024-03  PLANT 1    CC001P01  599.164174  FG01
# 3  2024-04  PLANT 1    CC001P01  323.828415  FG01
# 4  2024-05  PLANT 1    CC001P01  420.530023  FG01

# %%
act.drop(columns=['COST'], inplace=True)
act = pd.melt(
    act, 
    id_vars=['PERIOD', 'PLANT', 'COST_CENTER', 'CAT_CC'], 
    value_vars=cost_elements['COST_ELEMENT'].tolist(), 
    var_name='COST_ELEMENT', 
    value_name='COST'
)

act.head(10).style.format({"COST": "{:,.2f}"})
# Out:
# <style type="text/css">
# </style>
# <table id="T_352d3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_352d3_level0_col0" class="col_heading level0 col0" >PERIOD</th>
#       <th id="T_352d3_level0_col1" class="col_heading level0 col1" >PLANT</th>
#       <th id="T_352d3_level0_col2" class="col_heading level0 col2" >COST_CENTER</th>
#       <th id="T_352d3_level0_col3" class="col_heading level0 col3" >CAT_CC</th>
#       <th id="T_352d3_level0_col4" class="col_heading level0 col4" >COST_ELEMENT</th>
#       <th id="T_352d3_level0_col5" class="col_heading level0 col5" >COST</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_352d3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_352d3_row0_col0" class="data row0 col0" >2024-01</td>
#       <td id="T_352d3_row0_col1" class="data row0 col1" >PLANT 1</td>
#       <td id="T_352d3_row0_col2" class="data row0 col2" >CC001P01</td>
#       <td id="T_352d3_row0_col3" class="data row0 col3" >Production</td>
#       <td id="T_352d3_row0_col4" class="data row0 col4" >RM</td>
#       <td id="T_352d3_row0_col5" class="data row0 col5" >5,960,242.21</td>
#     </tr>
#     <tr>
#       <th id="T_352d3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_352d3_row1_col0" class="data row1 col0" >2024-02</td>
#       <td id="T_352d3_row1_col1" class="data row1 col1" >PLANT 1</td>
#       <td id="T_352d3_row1_col2" class="data row1 col2" >CC001P01</td>
#       <td id="T_352d3_row1_col3" class="data row1 col3" >Production</td>
#       <td id="T_352d3_row1_col4" class="data row1 col4" >RM</td>
#       <td id="T_352d3_row1_col5" class="data row1 col5" >5,878,986.92</td>
#     </tr>
#     <tr>
#       <th id="T_352d3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_352d3_row2_col0" class="data row2 col0" >2024-03</td>
#       <td id="T_352d3_row2_col1" class="data row2 col1" >PLANT 1</td>
#       <td id="T_352d3_row2_col2" class="data row2 col2" >CC001P01</td>
#       <td id="T_352d3_row2_col3" class="data row2 col3" >Production</td>
#       <td id="T_352d3_row2_col4" class="data row2 col4" >RM</td>
#       <td id="T_352d3_row2_col5" class="data row2 col5" >7,170,620.70</td>
#     </tr>
#     <tr>
#       <th id="T_352d3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_352d3_row3_col0" class="data row3 col0" >2024-04</td>
#       <td id="T_352d3_row3_col1" class="data row3 col1" >PLANT 1</td>
#       <td id="T_352d3_row3_col2" class="data row3 col2" >CC001P01</td>
#       <td id="T_352d3_row3_col3" class="data row3 col3" >Production</td>
#       <td id="T_352d3_row3_col4" class="data row3 col4" >RM</td>
#       <td id="T_352d3_row3_col5" class="data row3 col5" >6,416,939.68</td>
#     </tr>
#     <tr>
#       <th id="T_352d3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_352d3_row4_col0" class="data row4 col0" >2024-05</td>
#       <td id="T_352d3_row4_col1" class="data row4 col1" >PLANT 1</td>
#       <td id="T_352d3_row4_col2" class="data row4 col2" >CC001P01</td>
#       <td id="T_352d3_row4_col3" class="data row4 col3" >Production</td>
#       <td id="T_352d3_row4_col4" class="data row4 col4" >RM</td>
#       <td id="T_352d3_row4_col5" class="data row4 col5" >5,413,411.69</td>
#     </tr>
#     <tr>
#       <th id="T_352d3_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_352d3_row5_col0" class="data row5 col0" >2024-06</td>
#       <td id="T_352d3_row5_col1" class="data row5 col1" >PLANT 1</td>
#       <td id="T_352d3_row5_col2" class="data row5 col2" >CC001P01</td>
#       <td id="T_352d3_row5_col3" class="data row5 col3" >Production</td>
#       <td id="T_352d3_row5_col4" class="data row5 col4" >RM</td>
#       <td id="T_352d3_row5_col5" class="data row5 col5" >8,877,304.71</td>
#     </tr>
#     <tr>
#       <th id="T_352d3_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_352d3_row6_col0" class="data row6 col0" >2024-07</td>
#       <td id="T_352d3_row6_col1" class="data row6 col1" >PLANT 1</td>
#       <td id="T_352d3_row6_col2" class="data row6 col2" >CC001P01</td>
#       <td id="T_352d3_row6_col3" class="data row6 col3" >Production</td>
#       <td id="T_352d3_row6_col4" class="data row6 col4" >RM</td>
#       <td id="T_352d3_row6_col5" class="data row6 col5" >7,127,142.58</td>
#     </tr>
#     <tr>
#       <th id="T_352d3_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_352d3_row7_col0" class="data row7 col0" >2024-08</td>
#       <td id="T_352d3_row7_col1" class="data row7 col1" >PLANT 1</td>
#       <td id="T_352d3_row7_col2" class="data row7 col2" >CC001P01</td>
#       <td id="T_352d3_row7_col3" class="data row7 col3" >Production</td>
#       <td id="T_352d3_row7_col4" class="data row7 col4" >RM</td>
#       <td id="T_352d3_row7_col5" class="data row7 col5" >6,583,220.03</td>
#     </tr>
#     <tr>
#       <th id="T_352d3_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_352d3_row8_col0" class="data row8 col0" >2024-09</td>
#       <td id="T_352d3_row8_col1" class="data row8 col1" >PLANT 1</td>
#       <td id="T_352d3_row8_col2" class="data row8 col2" >CC001P01</td>
#       <td id="T_352d3_row8_col3" class="data row8 col3" >Production</td>
#       <td id="T_352d3_row8_col4" class="data row8 col4" >RM</td>
#       <td id="T_352d3_row8_col5" class="data row8 col5" >5,625,152.64</td>
#     </tr>
#     <tr>
#       <th id="T_352d3_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_352d3_row9_col0" class="data row9 col0" >2024-10</td>
#       <td id="T_352d3_row9_col1" class="data row9 col1" >PLANT 1</td>
#       <td id="T_352d3_row9_col2" class="data row9 col2" >CC001P01</td>
#       <td id="T_352d3_row9_col3" class="data row9 col3" >Production</td>
#       <td id="T_352d3_row9_col4" class="data row9 col4" >RM</td>
#       <td id="T_352d3_row9_col5" class="data row9 col5" >7,091,830.82</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ---
#
# # Output
#
# ### Cost

# %%
BP.merge(
    cost_elements,
    how='left',
    left_on='COST_ELEMENT',
    right_on='COST_ELEMENT'
)[['PERIOD', 'PLANT', 'COST_CENTER', 'CAT_CC', 'CAT_GL', 'COST_ELEMENT', 'COST']].merge(
    act,
    how='outer',
    left_on=['PERIOD', 'PLANT', 'COST_CENTER', 'CAT_CC', 'COST_ELEMENT'],
    right_on=['PERIOD', 'PLANT', 'COST_CENTER', 'CAT_CC', 'COST_ELEMENT'],
    suffixes=('_BP', '_ACT')
).to_excel("FACT_COST.xlsx", index=False)

# %%
BP_QTY[['PERIOD', 'PLANT', 'COST_CENTER', 'FG', 'QTY']].merge(
    act_QTY,
    how='outer',
    left_on=['PERIOD', 'PLANT', 'COST_CENTER', 'FG'],
    right_on=['PERIOD', 'PLANT', 'COST_CENTER', 'FG'],
    suffixes=('_BP', '_ACT')
).to_excel("FACT_QTY.xlsx", index=False)

# %%
BP.merge(
    cost_elements,
    how='left',
    left_on='COST_ELEMENT',
    right_on='COST_ELEMENT'
)
# Out:
#        PERIOD    PLANT COST_CENTER      CAT_CC COST_ELEMENT          COST  \
# 0     2024-01  PLANT 1    CC001P01  Production           RM  6.907105e+06
# 1     2024-02  PLANT 1    CC001P01  Production           RM  6.752731e+06
# 2     2024-03  PLANT 1    CC001P01  Production           RM  6.882021e+06
# 3     2024-04  PLANT 1    CC001P01  Production           RM  6.748523e+06
# 4     2024-05  PLANT 1    CC001P01  Production           RM  5.171938e+06
# ...       ...      ...         ...         ...          ...           ...
# 5635  2025-08  PLANT 6    CC006S02  Supporting       OH_VAR  1.637127e+06
# 5636  2025-09  PLANT 6    CC006S02  Supporting       OH_VAR  3.997199e+06
# 5637  2025-10  PLANT 6    CC006S02  Supporting       OH_VAR  4.381948e+06
# 5638  2025-11  PLANT 6    CC006S02  Supporting       OH_VAR  2.332213e+06
# 5639  2025-12  PLANT 6    CC006S02  Supporting       OH_VAR  2.485230e+06
#
#      CAT_GL
# 0        DM
# 1        DM
# 2        DM
# 3        DM
# 4        DM
# ...     ...
# 5635     OH
# 5636     OH
# 5637     OH
# 5638     OH
# 5639     OH
#
# [5640 rows x 7 columns]
